# %%
# belajar normalisasi di python
# from sklearn.preprocessing import MinMaxScaler
# data = [[12000000, 33], [35000000, 45], [4000000,23], [6500000, 26]]
# scaler = MinMaxScaler()
# scaler.fit(data)
# print(scaler.transform(data))

# belajar standarisasi
from sklearn import preprocessing
data = [[12000000, 33], [35000000, 45], [4000000,23], [6500000, 26]]
scaler = preprocessing.StandardScaler().fit(data)
data = scaler.transform(data)
data
# Out:
# array([[-0.19380693,  0.14763465],
#        [ 1.68306022,  1.56492728],
#        [-0.84663029, -1.03344254],
#        [-0.64262299, -0.67911938]])
